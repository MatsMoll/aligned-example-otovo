# %% [markdown]
# # Breast Cancer Example
#
# This notebook will show some basic use cases for how Aladdin can be used as a feature store.
#
# This is based on a classic dataset for detecting breast cancer.
# We will try to walk through a potential thought process.
#
# ## Scenario
# We have been given a dataset of breast cancer scans, and want to see if we can detect malignant cancer cells.
#
# ### Load the feature store
# First thing we need is to load the feature store. This can be done by referencing a local file, which we will be doning here. But it can also be referencing a private S3 bucket, or a more developer friendly autogeneration by reading the feature views from the current directory. This can be done by running `FeatureStore.from_dir()`.
#
# Let's see how it can be done.

# %%
from aligned import FeatureStore, FileSource
from aligned.validation.pandera import PanderaValidator

# %%
# The online store, which use the online source
online_store = await FileSource.from_path("feature-store.json").feature_store()

# The offline store, which use the batch sources
feature_store: FeatureStore = online_store.offline_store()

# %% [markdown]
# # Explore a bit
#
# Before we begin, let's see which feature views we have availible

# %%
# The availible feature views / grouped features
list(feature_store.feature_views.keys())
# Out:
# ['breast_scans_radius',
#  'breast_scans_diagnosis',
#  'breast_scans_smoothness',
#  'breast_scans_area',
#  'breast_scans_compactness',
#  'breast_scans_raw',
#  'titanic']

# %% [markdown]
# # Load some data
#
# Let's load all the data from the feature view `titanic`. Aka the titanic data-set, but slightly modified in a few places.
#
# Furthermore, will this also fetch all the transformed features that we want!
# E.g: We have an `ordinal_sex` which encodes `male` as `0` and `female` as `1`. We also have them encoded as one-hot-encodings, and the `age` variable is standard scaled in `scaled_age` etc.

# %%
dataset = await feature_store.feature_view("titanic")\
    .all()\
    .to_df()

# %%
dataset.head(10)
# Out:
#    passenger_id  survived  Pclass  \
# 0             1     False       3
# 1             2      True       1
# 2             3      True       3
# 3             4      True       1
# 4             5     False       3
# 5             6     False       3
# 6             7     False       1
# 7             8     False       3
# 8             9      True       3
# 9            10      True       2
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J   other  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare  ... is_female is_male  floored_age  \
# 0      0         A/5 21171   7.2500  ...     False    True           22
# 1      0          PC 17599  71.2833  ...      True   False           38
# 2      0  STON/O2. 3101282   7.9250  ...      True   False           26
# 3      0            113803  53.1000  ...      True   False           35
# 4      0            373450   8.0500  ...     False    True           35
# 5      0            330877   8.4583  ...     False    True         <NA>
# 6      0             17463  51.8625  ...     False   False           54
# 7      1            349909  21.0750  ...     False    True            2
# 8      2            347742  11.1333  ...      True   False           27
# 9      0            237736  30.0708  ...      True   False           14
#
#    ordinal_sex     ratio  logical_and  logical_or  floor_ratio  \
# 0            0 -0.016261        False        True    -0.016261
# 1            1  0.018144         True        True     0.018144
# 2            1 -0.003690        False        True    -0.003690
# 3            1  0.014089         True        True     0.014089
# 4            0  0.014089        False        True     0.014089
# 5            0       NaN        False        True          NaN
# 6         <NA>  0.032160        False        True     0.032160
# 7            0 -0.833365        False       False    -0.833365
# 8            1 -0.001129         True        True    -0.001129
# 9            1 -0.062952         True        True    -0.062952
#
#    abs_scaled_age  inverted_is_mr
# 0        0.357734           False
# 1        0.689464           False
# 2        0.095934            True
# 3        0.493114           False
# 4        0.493114           False
# 5             NaN           False
# 6        1.736661           False
# 7        1.666730            True
# 8        0.030485           False
# 9        0.881332           False
#
# [10 rows x 32 columns]

# %% [markdown]
# # Validation
#
# Now for the eagle eyed will you notice that there is one instance that have `other` in the `sex` column, leading to a NA value in `ordinal_sex`. Now this may reduce the perfromance of our model, so we can delceare that as requiered. We can do the same thing for the `age` feature, making that one required.

# %%
validated_dataset = await feature_store.feature_view("titanic")\
    .all()\
    .validate(PanderaValidator())\
    .to_df()

# %%
validated_dataset.head(10)
# Out:
#    level_0  index  passenger_id  survived  Pclass  \
# 0        0      0             1     False       3
# 1        1      1             2      True       1
# 2        2      2             3      True       3
# 3        3      3             4      True       1
# 4        4      4             5     False       3
# 5        6      7             8     False       3
# 6        7      8             9      True       3
# 7        8      9            10      True       2
# 8        9     10            11      True       3
# 9       10     11            12      True       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                     Palsson, Master. Gosta Leonard    male   2.0      3
# 6  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 7                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 8                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 9                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#    Parch  ... is_female  is_male floored_age ordinal_sex     ratio  \
# 0      0  ...     False     True          22           0 -0.016261
# 1      0  ...      True    False          38           1  0.018144
# 2      0  ...      True    False          26           1 -0.003690
# 3      0  ...      True    False          35           1  0.014089
# 4      0  ...     False     True          35           0  0.014089
# 5      1  ...     False     True           2           0 -0.833365
# 6      2  ...      True    False          27           1 -0.001129
# 7      0  ...      True    False          14           1 -0.062952
# 8      1  ...      True    False           4           1 -0.383958
# 9      0  ...      True    False          58           1  0.034456
#
#    logical_and  logical_or  floor_ratio  abs_scaled_age  inverted_is_mr
# 0        False        True    -0.016261        0.357734           False
# 1         True        True     0.018144        0.689464           False
# 2        False        True    -0.003690        0.095934            True
# 3         True        True     0.014089        0.493114           False
# 4        False        True     0.014089        0.493114           False
# 5        False       False    -0.833365        1.666730            True
# 6         True        True    -0.001129        0.030485           False
# 7         True        True    -0.062952        0.881332           False
# 8        False        True    -0.383958        1.535831            True
# 9        False        True     0.034456        1.998460            True
#
# [10 rows x 34 columns]

# %% [markdown]
# Notice that we now have no missing values! 🚀

# %% [markdown]
# # Data set generation
#
# We have now loaded some data. However, A very common workflow is to create a train, test and validation set.
#
# This can also be done for supervised datasets as follows

# %%
dataset = await feature_store.feature_view("titanic")\
    .all()\
    .validate(PanderaValidator())\
    .test_size(0.2, target_column="survived")\
    .validation_size(0.2)\
    .use_df()

# %% [markdown]
# Notice we do not get 6 different variables back as `X_train, X_test, X_validate, y_train, y_test, y_validate = await ...`, but rather one variable that keeps them easily organized.
# Not only that, but we also have a reference to the combined dataset if we need that for some reason.
#
# And by default will it use a stratigic split, so you have an equal distribution between the classes in each dataset.

# %%
dataset.train_input.describe()
# Out:
#           sibsp  rounded_age  constant_filled_age  ceiled_age         age  \
# count     428.0        428.0           428.000000       428.0  428.000000
# mean   0.530374    29.189252            29.193925    29.21028   29.193925
# std    0.963752    14.382991            14.385073   14.391732   14.385073
# min         0.0          1.0             0.750000         1.0    0.750000
# 25%         0.0        20.75            20.875000        21.0   20.875000
# 50%         0.0         28.0            28.000000        28.0   28.000000
# 75%         1.0         37.0            37.000000        37.0   37.000000
# max         5.0         71.0            71.000000        71.0   71.000000
#
#        mean_filled_age      adding  subtracting  ordinal_sex       ratio  \
# count       428.000000  428.000000   428.000000        428.0  428.000000
# mean         29.193925   29.724299   -28.663551     0.385514   -0.068150
# std          14.385073   14.076627    14.750149     0.487286    0.287047
# min           0.750000    0.830000   -71.000000          0.0   -2.331390
# 25%          20.875000   21.000000   -37.000000          0.0   -0.020674
# 50%          28.000000   28.000000   -28.000000          0.0    0.001249
# 75%          37.000000   38.000000   -20.000000          1.0    0.016865
# max          71.000000   71.000000     4.000000          1.0    0.040131
#
#        scaled_age  floor_ratio  abs_scaled_age  floored_age
# count  428.000000   428.000000      428.000000        428.0
# mean     0.113108    -0.068150        0.726180    29.172897
# std      0.941501     0.287047        0.608830    14.388325
# min     -1.748543    -2.331390        0.030485          0.0
# 25%     -0.431365    -0.020674        0.231315        20.75
# 50%      0.034965     0.001249        0.554083         28.0
# 75%      0.624014     0.016865        1.082163         37.0
# max      2.849308     0.040131        2.849308         71.0

# %%
dataset.test_input.describe()
# Out:
#           sibsp  rounded_age  constant_filled_age  ceiled_age         age  \
# count     143.0        143.0           143.000000       143.0  143.000000
# mean    0.41958    28.237762            28.251189   28.272727   28.251189
# std    0.834237    14.215622            14.219054   14.207309   14.219054
# min         0.0          0.0             0.420000         1.0    0.420000
# 25%         0.0         19.0            19.000000        19.0   19.000000
# 50%         0.0         28.0            28.000000        28.0   28.000000
# 75%         1.0         35.5            35.500000        35.5   35.500000
# max         4.0         74.0            74.000000        74.0   74.000000
#
#        mean_filled_age      adding  subtracting  ordinal_sex       ratio  \
# count       143.000000  143.000000   143.000000        143.0  143.000000
# mean         28.251189   28.670769   -27.831608     0.370629   -0.111199
# std          14.219054   14.043557    14.440685     0.484671    0.494982
# min           0.420000    0.420000   -74.000000          0.0   -4.214621
# 25%          19.000000   19.500000   -35.000000          0.0   -0.029162
# 50%          28.000000   28.000000   -27.000000          0.0    0.001249
# 75%          35.500000   36.000000   -19.000000          1.0    0.014802
# max          74.000000   74.000000     2.000000          1.0    0.041158
#
#        scaled_age  floor_ratio  abs_scaled_age  floored_age
# count  143.000000   143.000000      143.000000        143.0
# mean     0.051406    -0.111199        0.710618    28.223776
# std      0.930635     0.494982        0.600174    14.243071
# min     -1.770141    -4.214621        0.030485          0.0
# 25%     -0.554083    -0.029162        0.231315         19.0
# 50%      0.034965     0.001249        0.554083         28.0
# 75%      0.525839     0.014802        1.079922         35.5
# max      3.045658     0.041158        3.045658         74.0

# %%
dataset.validate_input.describe()
# Out:
#           sibsp  rounded_age  constant_filled_age  ceiled_age         age  \
# count     142.0        142.0           142.000000       142.0  142.000000
# mean   0.556338    32.507042            32.508803   32.514085   32.508803
# std     0.91887    14.889544            14.891344   14.885728   14.891344
# min         0.0          1.0             0.750000         1.0    0.750000
# 25%         0.0        21.25            21.250000       21.25   21.250000
# 50%         0.0         31.0            31.000000        31.0   31.000000
# 75%         1.0         42.0            42.000000        42.0   42.000000
# max         5.0         80.0            80.000000        80.0   80.000000
#
#        mean_filled_age      adding  subtracting  ordinal_sex       ratio  \
# count       142.000000  142.000000   142.000000        142.0  142.000000
# mean         32.508803   33.065141   -31.952465     0.302817   -0.027846
# std          14.891344   14.672962    15.162358     0.461103    0.214152
# min           0.750000    2.750000   -80.000000          0.0   -2.331390
# 25%          21.250000   21.250000   -41.750000          0.0   -0.019179
# 50%          31.000000   32.000000   -30.000000          0.0    0.007462
# 75%          42.000000   42.000000   -21.000000          1.0    0.022649
# max          80.000000   80.000000     1.250000          1.0    0.042979
#
#        scaled_age  floor_ratio  abs_scaled_age  floored_age
# count  142.000000   142.000000      142.000000        142.0
# mean     0.330066    -0.027846        0.796597         32.5
# std      0.974636     0.214152        0.648509    14.904781
# min     -1.748543    -2.331390        0.030485          0.0
# 25%     -0.406821    -0.019179        0.296765        21.25
# 50%      0.231315     0.007462        0.558564         31.0
# 75%      0.951263     0.022649        1.193339         42.0
# max      3.438357     0.042979        3.438357         80.0

# %% [markdown]
# ## Real time data
#
# One of the hard problems `aligned` tries to solve, is keeping all features consistent across offline, and online feature stores.
#
# Lets simulate how it could look.

# %% [markdown]
# The following code will only work if you connect to a redis cluster. Either by having it run locally with `brew install redis` on MacOS, or running it in a Docker container

# %%
import os
# Set the online redis url
os.environ['REDIS_URL'] = "redis://localhost:6379"

# %% [markdown]
# We need to populate the store with some data, so why not send in some "new" passenger information, and see how it handles it.
#
# Also be aware that currently can any feature be left out, and it will be filled with `None`. This may chagne in the future in order inforce better quality control.

# %%
online_store.feature_view("titanic").write_input
# Out:
# {'age', 'cabin', 'name', 'passenger_id', 'sex', 'sibsp', 'survived'}

# %%
await online_store.feature_view("titanic")\
    .write({
        'passenger_id': [10001, 10002, 10003, 10004],
        'age': [25, 54, None, None],
        'cabin': [None, "A40", "C53", None],
        'sex': ["male", "male", "female", "other"],
        'sibsp': [2, 0, 0, 3]
    })

# %% [markdown]
# ### Fetch the new values
#
# The above code simulated a write to the online database. This can originate from any stream process you want.
#
# Either a Kafka stream, Redis stream, or mayby simpler a HTTP POST command.
#
# However, there is no value in storing the values if we can't fetch them.
#
# So let's get our new values for `passenger_id = [10001, 10002, 10003, 10004]`.

# %%
data_subset = await online_store.features_for({
    "passenger_id": [10001, 10002, 10003, 10004, 10005]
}, features=[
    "titanic:scaled_age",
    "titanic:age",
    "titanic:mean_filled_age",
    "titanic:ordinal_sex",
    "titanic:is_male",
    "titanic:is_female",
    "titanic:abs_scaled_age",
    "titanic:cabin"
]).to_df()
data_subset
# Out:
#    passenger_id   age  mean_filled_age  scaled_age cabin  abs_scaled_age  \
# 0         10001  25.0        25.000000   -0.161384   NaN        0.161384
# 1         10002  54.0        54.000000    1.736661   A40        1.736661
# 2         10003   NaN        27.465769         NaN   C53             NaN
# 3         10004   NaN        27.465769         NaN   NaN             NaN
# 4         10005   NaN              NaN         NaN   NaN             NaN
#
#   is_female is_male  ordinal_sex
# 0     False    True            0
# 1     False    True            0
# 2      True   False            1
# 3     False   False         <NA>
# 4       NaN     NaN         <NA>

# %% [markdown]
# Look at that! We now have our processed values, which is scaled based using a `StandardScaler`, aka the amount of standard diviations from the mean.
# And we have the original values as reference.
# All this without implementing a single line of transformation logic our self.

# %% [markdown]
# However, we still have a small problem. As it is kind of painfull writing out all the fetures we want to inclued each time. So how could we make this even simpler?
#
# Thats where Model Services come in.

# %% [markdown]
# ## Model Service

# %%
online_store.all_models
# Out:
# ['cancer_detection', 'titanic_model']

# %%
model_data = await online_store.model("titanic_model").features_for({
    'passenger_id': [10001, 10002, 10003, 10004, 10005]
}).to_df()
model_data
# Out:
#    rounded_age  sibsp  constant_filled_age     sex  ceiled_age  passenger_id  \
# 0           25      2                 25.0    male          25         10001
# 1           54      0                 54.0    male          54         10002
# 2         <NA>      0                  0.0  female        <NA>         10003
# 3         <NA>      3                  0.0   other        <NA>         10004
# 4         <NA>   <NA>                  NaN     NaN        <NA>         10005
#
#   is_mr   age  mean_filled_age survived  ...  logical_and scaled_age  \
# 0  True  25.0        25.000000     True  ...         True  -0.161384
# 1  True  54.0        54.000000     True  ...         True   1.736661
# 2  True   NaN        27.465769     True  ...         True        NaN
# 3  True   NaN        27.465769     True  ...         True        NaN
# 4   NaN   NaN              NaN      NaN  ...          NaN        NaN
#
#   logical_or  has_siblings floor_ratio  abs_scaled_age  inverted_is_mr  \
# 0       True          True   -0.006455        0.161384           False
# 1       True         False    0.032160        1.736661           False
# 2       True         False         NaN             NaN           False
# 3       True          True         NaN             NaN           False
# 4        NaN           NaN         NaN             NaN             NaN
#
#   is_female  is_male floored_age
# 0     False     True          25
# 1     False     True          54
# 2      True    False        <NA>
# 3     False    False        <NA>
# 4       NaN      NaN        <NA>
#
# [5 rows x 27 columns]
